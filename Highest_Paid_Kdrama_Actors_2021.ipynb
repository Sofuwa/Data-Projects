# %% [markdown]
# # Highest Paid K-drama Actors 2021

# %% [markdown]
# _This is a notebook by Sofuwa Oluwafunmilayo._

# %% [markdown]
# ## Contents
#
# [1. Import Libraries](#Import-Libraries)
#
# [2. Scrape the website with the information on the highest paid K-drama actors](#Scrape-the-website-with-the-information-on-the-highest-paid-K-drama-actors)
#
# [3. Scrape each actor's Wikipedia page](#Scrape-each-actor's-Wikipedia-page)
#
# [4. Creating the actor's dataframe](#Creating-the-actor's-dataframe)
#
# [5. Scraping information from IMDb](#Scraping-information-from-IMDb)
#
# [6. Creating the IMDb dataframe](#Creating-the-IMDb-dataframe)
#
# [7. Scraping the series images](#Scraping-the-series-images)
#
# [8. Downloading the data tables](#Downloading-the-data-tables)
#
# [9. Link to Other Pages](#Link-to-Other-Pages)

# %% [markdown]
# ## Import Libraries

# %%
from bs4 import BeautifulSoup as bs
import requests
import re
import pandas as pd
import os

# %% [markdown]
# ## Scrape the website with the information on the highest paid K-drama actors

# %%
request_1 = requests.get("https://seoulspace.com/richest-kdrama-actors-highest-paid-actors-in-korean-dramas/", "html.parser")
# Convert to a beautiful soup object
first_soup = bs(request_1.content)

# %% [markdown]
# I will be extracting the fees per episode for each actor listed in the website. I will also get the summary of each actor as well as the actor's name from the website.

# %%
fee_per_episode=[]
summary = []
actor = []

info_box = first_soup.find(class_="entry-content")
info_fees = info_box.find_all("p")[3::3]
info_summary = info_box.find_all("p")[2::3]
info_actor = first_soup.find_all("h2")[0:10]

for row in info_fees:
    fee_per_episode.append(row.get_text().replace('\xa0',''))
for row in info_summary:
    summary.append(row.get_text().replace('\xa0',''))
for row in info_actor:
    actor.append(row.get_text().replace('\xa0',''))

# %% [markdown]
# ## Scrape each actor's Wikipedia page

# %% [markdown]
# Get more information on each actor from their wikipedia page

# %%
# The wikipedia url for these actors have a similar format. To get the url:
# Firstly, I have to transform the actors name from the result i got in the 'actor' variable. Names that contain hyphen have to change.
# For example Kim Soo-Hyun will change to Kim Soo-hyun. The character that comes immediately after the hyphen has to be lowercased.
# Secondly, replace spaces with an underscore

actor_1 = [re.sub("([-])\s*([a-zA-Z])", lambda p: p.group(0).lower(), a) for a in actor]
actor_1 = [a.replace(' ','_') for a in actor_1]

base_url = 'https://en.wikipedia.org/wiki/'
actor_url = [(base_url + a) for a in actor_1]
actor_url
# Out:
# ['https://en.wikipedia.org/wiki/Kim_Soo-hyun',
#  'https://en.wikipedia.org/wiki/So_Ji-sub',
#  'https://en.wikipedia.org/wiki/Hyun_Bin',
#  'https://en.wikipedia.org/wiki/Lee_Min-ho',
#  'https://en.wikipedia.org/wiki/Ji_Chang-wook',
#  'https://en.wikipedia.org/wiki/Jo_In-sung',
#  'https://en.wikipedia.org/wiki/Yoo_Ah-in',
#  'https://en.wikipedia.org/wiki/Lee_Jong-suk',
#  'https://en.wikipedia.org/wiki/Lee_Seung-gi',
#  'https://en.wikipedia.org/wiki/Song_Joong-ki']

# %%
actor_dob = []
actor_age = []

for link in actor_url:
  request_2 = requests.get(link, "html.parser")
  second_soup = bs(request_2.content)
  info_box = second_soup.find(class_="infobox-data")
  
  info_box_text = info_box.get_text()

# I want to get the dob (date of birth) and the format I want to extract is between the first closing and second closing brackets. For
# example, (1985-09-19) September 19, 1985 (age 36)Dong District, Daejeon, South Korea
# This extraction method uses the logic of indexing and slicing.
  dob_start = ') '
  dob_end = ' ('
  s = info_box_text
  actor_dob.append(s[s.find(dob_start)+len(dob_start):s.rfind(dob_end)].replace(",",""))

# Applying the above step to extract the actor's age. The difference here is the start and end characters i'll use for the extraction. 
  age_start = '\xa0'
  age_end = ')'
  s = info_box_text
  actor_age.append(s[s.find(age_start)+len(age_start):s.rfind(age_end)])

# %% [markdown]
# ## Creating the actor's dataframe

# %%
actors_df = pd.DataFrame()
actors_df['Actor'] = actor
actors_df['Date of Birth'] = actor_dob
actors_df['Age'] = actor_age
actors_df['Earnings Per Episode'] = fee_per_episode
actors_df['Information'] = summary

# Clean up the data
actors_df['Earnings Per Episode'] = actors_df['Earnings Per Episode'].str.replace("$", "")
to_drop = {"Fee per episode": "",",":"",": ":""}
actors_df['Earnings Per Episode'] = actors_df['Earnings Per Episode'].replace(to_drop, regex=True)
# Convert earnings per episode from string to integer
actors_df['Earnings Per Episode'] = actors_df['Earnings Per Episode'].astype(int) 

actors_df
# Out:
#            Actor  ...                                        Information
# 0   Kim Soo-Hyun  ...  Kim Soo Hyun has become the most popular Kdram...
# 1      So Ji-sub  ...  So Ji-sub is one of the hardest working K-Dram...
# 2       Hyun Bin  ...  Hyun Bin has been doing Korean dramas for a wh...
# 3     Lee Min-ho  ...  Lee Min-ho started doing Korean dramas back in...
# 4  Ji Chang-wook  ...  Ji Chang-wook really does it all. He has starr...
# 5     Jo In-Sung  ...  It is crazy to think that Jo In-Sung is alread...
# 6      Yoo Ah-in  ...  Yoo Ah-in is one of the most in-demand Korean ...
# 7   Lee Jong-suk  ...  Many Kdrama fans might not know this but Lee J...
# 8   Lee Seung-gi  ...  Fans of Lee Seung-gi love his innocent look an...
# 9  Song Joong-ki  ...  Song Joong-ki has worldwide appeal thanks to t...
#
# [10 rows x 5 columns]

# %% [markdown]
# ## Scraping information from IMDb

# %% [markdown]
# To get information from IMDb, I made use of the advanced search url to search for each actor's name. Unlike Wikipedia, IMDb uses '+' rather than '_' to replace spaces. I also had to make a change to one of the actor's name as his Wikipedia's name and IMDb's name were spelt a little bit differently.

# %%
actor_2 = [a.replace('So_Ji-sub','So_Ji-seob') for a in actor_1]
actor_2 = [a.replace('_','+') for a in actor_2]
actor_2

base_imdb_url = 'https://www.imdb.com/search/name/?name='
actor_imdb_search = [(base_imdb_url + a) for a in actor_2]
actor_imdb_search
# Out:
# ['https://www.imdb.com/search/name/?name=Kim+Soo-hyun',
#  'https://www.imdb.com/search/name/?name=So+Ji-seob',
#  'https://www.imdb.com/search/name/?name=Hyun+Bin',
#  'https://www.imdb.com/search/name/?name=Lee+Min-ho',
#  'https://www.imdb.com/search/name/?name=Ji+Chang-wook',
#  'https://www.imdb.com/search/name/?name=Jo+In-sung',
#  'https://www.imdb.com/search/name/?name=Yoo+Ah-in',
#  'https://www.imdb.com/search/name/?name=Lee+Jong-suk',
#  'https://www.imdb.com/search/name/?name=Lee+Seung-gi',
#  'https://www.imdb.com/search/name/?name=Song+Joong-ki']

# %% [markdown]
# After getting the search url, I would get the url of the first name on the page. This is because IMDb assigns a certain number to things on their site eg actors, movies etc. These numbers are included in the url rather than the actor's name.

# %%
actor_imdb_url = []

for url in actor_imdb_search:
  request_3  = requests.get(url, "html.parser")
  third_soup = bs(request_3.content)
  base_actor_url = 'https://www.imdb.com'
  first_url  = third_soup.find(class_="lister-item-header")
  second_url = first_url.find('a')['href']
  third_url  = base_actor_url + second_url
  actor_imdb_url.append(third_url)
actor_imdb_url
# Out:
# ['https://www.imdb.com/name/nm4633543',
#  'https://www.imdb.com/name/nm1234414',
#  'https://www.imdb.com/name/nm1593460',
#  'https://www.imdb.com/name/nm3316279',
#  'https://www.imdb.com/name/nm3865611',
#  'https://www.imdb.com/name/nm1251770',
#  'https://www.imdb.com/name/nm2584860',
#  'https://www.imdb.com/name/nm4062328',
#  'https://www.imdb.com/name/nm3876951',
#  'https://www.imdb.com/name/nm3609366']

# %% [markdown]
# For each of the url above, I will get only information about tv series that each actor has acted in. This information will include the series title, url and the actor's name.

# %%
series_title = []
series_url = []
series_actor = []

for url in actor_imdb_url:
  request_4 = requests.get(url, "html.parser")
  fourth_soup = bs(request_4.content)
  fourth_url = fourth_soup.find("div",class_="filmo-category-section")
  get_url = fourth_url.find_all('b')

#get just the series title and url
  just_series = []
  for i in get_url:
    if i.next_sibling.strip() == '(TV Series)' or i.next_sibling.strip() == '(TV Mini Series)':
      just_series.append(i)

#get the series title
  for i in range(len(just_series)):
    series_name = just_series[i].get_text()
    series_title.append(series_name)

#get the series url
    imdb_url = just_series[i].find('a')['href']
    base_url = 'https://www.imdb.com/'
    full_url = base_url + imdb_url
    series_url.append(full_url)

# make the actor's name the same length as the result from series_title
    actor_name = fourth_soup.find(class_="itemprop").get_text()
    series_actor.append(actor_name)
    series_actor*len(series_title)

# %%
#check if all variables are the same length
len(series_title),len(series_url),len(series_actor)
# Out:
# (130, 130, 130)

# %% [markdown]
# Using the series url, I will get the alternative title, imdb rating, summary, year when it was released and the genre for each series.

# %%
also_known_as = []
imdb_rating = []
series_summary = []
release_year = []
genre = []

for url in series_url:
  request_5 = requests.get(url, "html.parser")
  fifth_soup = bs(request_5.content)
  
  alt_title = fifth_soup.find("li",attrs={"data-testid":"title-details-akas"})
  if alt_title is not None:
    also_known_as.append(alt_title.get_text().replace('Also known as',''))
  else:
    also_known_as.append('No alternative title')

  rating = fifth_soup.find("div",class_="AggregateRatingButton__Rating-sc-1ll29m0-2 bmbYRW")
  if rating is not None:
    imdb_rating.append(rating.get_text())
  else:
    imdb_rating.append('No IMDb rating')

  summary = fifth_soup.find(class_="GenresAndPlot__TextContainerBreakpointXS_TO_M-cum89p-0 dcFkRD")
  if summary is not None:
    if summary.find('a') in summary:
      #some summaries have a link such as a'read all' link that allows individuals to read the full summary
      #for such summaries, i would follow the link and get the full summary from the first paragraph
      summary_url = url + summary.find('a')['href']
      request_6 = requests.get(summary_url, "html.parser")
      sixth_soup = bs(request_6.content)
      series_summary.append(sixth_soup.find('p').get_text())
    else:
      series_summary.append(summary.get_text())
  else:
    series_summary.append('No IMDb movie summary')

  r_year = fifth_soup.find("span",class_="TitleBlockMetaData__ListItemText-sc-12ein40-2 jedhex")
  if r_year is not None:
    year = r_year.get_text()
    #get only the first four characters
    release_year.append(year[:4])
  else:
    release_year.append('No year specified')

  s_genre = fifth_soup.find_all('a',class_="GenresAndPlot__GenreChip-cum89p-3 fzmeux ipc-chip ipc-chip--on-baseAlt")
  if s_genre is not None:
    s_genre_1 = [i.get_text() for i in s_genre]
    genre.append(s_genre_1)
  else:
    genre.append('No genre specified')

#replace summaries that have string length below 1
series_summary = ['No IMDb movie summary' if len(s) < 1 else s for s in series_summary]

#convert each list in the 'genre' variable to a string
genre = [', '.join(i) for i in genre]

#replace genres that have string length below 1
genre = ['No genre specified' if len(g) < 1 else g for g in genre]

# %%
len(imdb_rating),len(also_known_as),len(series_summary), len(release_year), len(genre)
# Out:
# (130, 130, 130, 130, 130)

# %% [markdown]
# ## Creating the IMDb dataframe

# %%
imdb_df = pd.DataFrame()
imdb_df['Actor'] = series_actor
imdb_df['Year'] = release_year
imdb_df['Film Title'] = series_title
imdb_df['Also Known As'] = also_known_as
imdb_df['Genre'] = genre

imdb_df['IMDb Rating'] = imdb_rating
imdb_df['IMDb Summary'] = series_summary

pd.set_option('display.max_rows', None)

imdb_df
# Out:
#              Actor  ...                                       IMDb Summary
# 0     Kim Soo-hyun  ...  A remake of the BBC drama "Criminal Justice" t...
# 1     Kim Soo-hyun  ...  An extraordinary road to emotional healing ope...
# 2     Kim Soo-hyun  ...  The absolute top secret love story of a chaebo...
# 3     Kim Soo-hyun  ...  When he's invited to manage a hotel for dead s...
# 4     Kim Soo-hyun  ...  A group of young television producers--Ra Joon...
# 5     Kim Soo-hyun  ...  Do Min-Joon, an alien that came to our planet ...
# 6     Kim Soo-hyun  ...  Revolves on the competition between western an...
# 7     Kim Soo-hyun  ...  The story of the secret love between Lee Hwon,...
# 8     Kim Soo-hyun  ...  Dream High tells the story of six students at ...
# 9     Kim Soo-hyun  ...  This drama tells the story of three siblings w...
# 10    Kim Soo-hyun  ...  Cha Kang Jin is the son of barmaid, Cha Chun H...
# 11    Kim Soo-hyun  ...  How is it to be a teenager in today's Korean s...
# 12      So Ji-seob  ...  Go Ae Rin suddenly loses her husband. A myster...
# 13      So Ji-seob  ...  A lawyer in her thirties coming out of a long ...
# 14      So Ji-seob  ...  A romantic drama of a man and a woman of oppos...
# 15      So Ji-seob  ...  Follows the story of a man who goes to Jeju Is...
# 16      So Ji-seob  ...  Tae Gong Sil has the ability to see ghosts, bu...
# 17      So Ji-seob  ...  A drama based on a cyber investigation squad. ...
# 18      So Ji-seob  ...  The story revolves around two young soldiers, ...
# 19      So Ji-seob  ...  Based on the biblical story of Adam and Eve's ...
# 20      So Ji-seob  ...  Ji Sub is coming back home after an unsuccessf...
# 21      So Ji-seob  ...  Mu-Hyuk, a Korean adopted to Australia, is a t...
# 22      So Ji-seob  ...  Lee Soo Jung is scraping by as a tour guide in...
# 23      So Ji-seob  ...  More than a thousand years ago from the presen...
# 24      So Ji-seob  ...  Ho-Jung is a cute, naive girl who often falls ...
# 25      So Ji-seob  ...  This drama is about the lives of Tae Hee and Y...
# 26      So Ji-seob  ...  All's fair in love and war - and in competitio...
# 27      So Ji-seob  ...                              No IMDb movie summary
# 28      So Ji-seob  ...  Song Kyung-rin is a fashion designer, but afte...
# 29        Hyun Bin  ...  The absolute top secret love story of a chaebo...
# 30        Hyun Bin  ...  After suffering a setback following a friend's...
# 31        Hyun Bin  ...  Koo Seo-Jin (Hyun-Bin) has two different perso...
# 32        Hyun Bin  ...  A rich young CEO falls for a poor stuntwoman d...
# 33        Hyun Bin  ...  True friends watch out for one another and pro...
# 34        Hyun Bin  ...                 Story of lives of drama directors.
# 35        Hyun Bin  ...  This is about how three people crossing fates ...
# 36        Hyun Bin  ...  At 17, Tae Woong, a mathematical genius, meets...
# 37        Hyun Bin  ...  The misadventures and romantic entanglements o...
# 38        Hyun Bin  ...  A westernized Irish adoptee, Joong-Ah inevitab...
# 39      Lee Min-Ho  ...  A modern-day Korean emperor passes through a m...
# 40      Lee Min-Ho  ...  The television series centers on the love stor...
# 41      Lee Min-Ho  ...  Two young people who have been friends for a l...
# 42      Lee Min-Ho  ...  Min Ho, a music producer who is struggling to ...
# 43      Lee Min-Ho  ...  After a chance encounter in LA, two teens from...
# 44      Lee Min-Ho  ...  When the queen-to-be of medieval Korea is badl...
# 45      Lee Min-Ho  ...  Our hero suddenly rises from a coma. He has no...
# 46      Lee Min-Ho  ...  Lee Yun-seong was trained by his father's best...
# 47      Lee Min-Ho  ...  The surprise hit of 2010, Personal Taste (aka ...
# 48      Lee Min-Ho  ...  A 25-minute "music drama" will wrap up the F4 ...
# 49      Lee Min-Ho  ...  Poor girl attends the elite Shin Hwa High and ...
# 50      Lee Min-Ho  ...  The story focuses on the conflicts between the...
# 51      Lee Min-Ho  ...  Cha Gong Chan was able to enter the top privat...
# 52      Lee Min-Ho  ...  Modern students experience considerable stress...
# 53      Lee Min-Ho  ...  The misadventures of Doraemon, a robot cat fro...
# 54      Lee Min-Ho  ...                              No IMDb movie summary
# 55   Ji Chang-Wook  ...  Heart stolen by a free-spirited woman after a ...
# 56   Ji Chang-Wook  ...  A former troublemaker applies for a job at a c...
# 57   Ji Chang-Wook  ...  This Is a sci-fi romantic comedy. The story te...
# 58   Ji Chang-Wook  ...  Eun Bong Hee is a prosecutor trainee who unfor...
# 59   Ji Chang-Wook  ...  Kim Je Ha is a former soldier for hire. He is ...
# 60   Ji Chang-Wook  ...  Can a young woman regain her passion for marti...
# 61   Ji Chang-Wook  ...  An old murder incident involving a group who r...
# 62   Ji Chang-Wook  ...  Five romance stories about each of the girls o...
# 63   Ji Chang-Wook  ...  A Korea-born warrior girl had to be a servant ...
# 64   Ji Chang-Wook  ...  Young people struggling to overcome their trag...
# 65   Ji Chang-Wook  ...  Based on the true story of a young man who tur...
# 66   Ji Chang-Wook  ...  Childhood friends Baek Dong Soo and Yeo Woon a...
# 67   Ji Chang-Wook  ...  Raised in America by his mentally handicapped ...
# 68   Ji Chang-Wook  ...                              No IMDb movie summary
# 69      In-Sung Jo  ...  Depict the life story of the ones in their twi...
# 70      In-Sung Jo  ...  A love story between a psychiatrist named Ji H...
# 71      In-Sung Jo  ...  The story of Oh Soo, a well known gambler and ...
# 72      In-Sung Jo  ...  Mini series about a woman who was given up for...
# 73      In-Sung Jo  ...  Lee Soo Jung is scraping by as a tour guide in...
# 74      In-Sung Jo  ...  Film star Jeon Do-Yeon (Untold Scandal, Lovers...
# 75      In-Sung Jo  ...  Left on his father's doorstep as a newborn, Pa...
# 76      In-Sung Jo  ...  Uhk Gwan is a gangster but one day, he discove...
# 77      In-Sung Jo  ...  A popular high-school student completely chang...
# 78      In-Sung Jo  ...  Each Nonstop season shows the hilarious everyd...
# 79       Yoo Ah-in  ...  People hear predictions on when they will die....
# 80       Yoo Ah-in  ...  Writers that lived under Japanese rule in the ...
# 81       Yoo Ah-in  ...  This drama tells of the love story that develo...
# 82       Yoo Ah-in  ...  Story of the the foundation of the Joseon Dyna...
# 83       Yoo Ah-in  ...  Han Yeo-reum and Nam Ha-jin are committed to e...
# 84       Yoo Ah-in  ...  A love story of a young poor student pianist f...
# 85       Yoo Ah-in  ...  Life Of Jang Ok Jung, Later Known As Jang Hee ...
# 86       Yoo Ah-in  ...  Fashion King tells the story of Lee Ga-young w...
# 87       Yoo Ah-in  ...  In the Joseon era, Kim Yoon-hee masquerades as...
# 88       Yoo Ah-in  ...  Cho Jae Hee is in his 40s and has yet to be ma...
# 89       Yoo Ah-in  ...  Kang Chil Woo was a lowly police officer durin...
# 90       Yoo Ah-in  ...                              No IMDb movie summary
# 91       Yoo Ah-in  ...  Chae-won is a charming woman, who is also tale...
# 92    Lee Jong-Suk  ...  Cha Eun Ho is a successful and handsome writer...
# 93    Lee Jong-Suk  ...  Kim Woo Jin is a stage drama writer while Kore...
# 94    Lee Jong-Suk  ...  The drama is about a woman, Nam Hong Joo, who ...
# 95    Lee Jong-Suk  ...  A coming-of-age story about a group of college...
# 96    Lee Jong-Suk  ...  The Starry Night is a Chinese-South Korean col...
# 97    Lee Jong-Suk  ...  A love story between a couple in their early t...
# 98    Lee Jong-Suk  ...  A young boy, whose life and family has been de...
# 99    Lee Jong-Suk  ...  As a child, Park Hoon (Lee Jong-suk) and his f...
# 100   Lee Jong-Suk  ...  The legal drama centers around Jang Hye Sung, ...
# 101   Lee Jong-Suk  ...  A popular high-school student completely chang...
# 102   Lee Jong-Suk  ...  The iconic "School Series" that ran from 1999-...
# 103   Lee Jong-Suk  ...  A weekly program on KBS2 showing short dramas,...
# 104   Lee Jong-Suk  ...  Lee Yoon-ho (Jung Il-Woo), a motorcycle mania ...
# 105   Lee Jong-Suk  ...  A rich young CEO falls for a poor stuntwoman d...
# 106   Lee Jong-Suk  ...  The writer of 2009 hit Shining Inheritance add...
# 107   Lee Seung-gi  ...                              No IMDb movie summary
# 108   Lee Seung-gi  ...  A suspenseful story that will center around th...
# 109   Lee Seung-gi  ...  Special episodes of "Mouse" which will highlig...
# 110   Lee Seung-gi  ...  A whodunit variety show featuring some of of t...
# 111   Lee Seung-gi  ...  An ordinary man who comes across surprising ci...
# 112   Lee Seung-gi  ...  In 2017, Son Oh Gong and Ma Wang are in confli...
# 113   Lee Seung-gi  ...  P4: are the new recruits in the violent crimes...
# 114   Lee Seung-gi  ...  A melodrama epic about the great deal of troub...
# 115   Lee Seung-gi  ...  The crown-prince of South Korea is forced to w...
# 116   Lee Seung-gi  ...  Chae Dae Wong, an aspiring actor, unwillingly ...
# 117   Lee Seung-gi  ...  After losing her father Go Eun-sung's stepmoth...
# 118  Song Joong-ki  ...  During a visit to his motherland, a Korean-Ita...
# 119  Song Joong-ki  ...  Arthdal Chronicles depicts the birth of civili...
# 120  Song Joong-ki  ...  Meet the twins, Bigfoot Kevin and Littlefoot T...
# 121  Song Joong-ki  ...  A secret agent works under cover as a bodyguar...
# 122  Song Joong-ki  ...  This drama tells of the love story that develo...
# 123  Song Joong-ki  ...  Kang Ma-Ru is a promising medical student, unt...
# 124  Song Joong-ki  ...  The misadventures of Doraemon, a robot cat fro...
# 125  Song Joong-ki  ...  A series of murders occurred during the reign ...
# 126  Song Joong-ki  ...  In the Joseon era, Kim Yoon-hee masquerades as...
# 127  Song Joong-ki  ...  Seo Hye Young is a talented second-year obstet...
# 128  Song Joong-ki  ...  Cha Kang Jin is the son of barmaid, Cha Chun H...
# 129  Song Joong-ki  ...                              No IMDb movie summary
#
# [130 rows x 7 columns]

# %% [markdown]
# ## Scraping the series images

# %% [markdown]
#  I want to get the images for the unique series in the data. I'll make use of these images in my Tableau visualization.

# %%
#get the unique series and url
unique_series=[]
for i in series_title:
    if i not in unique_series:
        unique_series.append(i)

unique_url=[]
for i in series_url:
    if i not in unique_url:
        unique_url.append(i)

# %%
#check if they are the same length
len(unique_series),len(unique_url)
# Out:
# (121, 121)

# %%
#check if the series name corresponds with the url
unique_series[50],unique_url[50]
# Out:
# ('Mackerel Run', 'https://www.imdb.com//title/tt4193068/')

# %% [markdown]
# Each series image in each of the unique url has a link that takes you to another imdb page. From this imdb page, I will get the actual image link.

# %%
image_imdb_url = []

for i in range(len(unique_url)):
  request_7 = requests.get(unique_url[i], "html.parser")
  seventh_soup = bs(request_7.content)
  imdb_url = seventh_soup.find("div",attrs={"data-testid":"hero-media__poster"})
  if imdb_url is not None:
    if imdb_url.find('a') in imdb_url:
      imdb_url_1 = imdb_url.find('a')['href']
      image_imdb_url.append(imdb_url_1)
    #not all these url contain a series image and therefore no image url so i'll return the index for such series
    else:
      image_imdb_url.append(i)
  else:
    image_imdb_url.append(i)

# %%
image_imdb_url
# Out:
# ['/title/tt14170016/mediaviewer/rm1566766593/?ref_=tt_ov_i',
#  '/title/tt12451520/mediaviewer/rm3671504129/?ref_=tt_ov_i',
#  '/title/tt10850932/mediaviewer/rm3056777473/?ref_=tt_ov_i',
#  '/title/tt10220588/mediaviewer/rm2995232513/?ref_=tt_ov_i',
#  '/title/tt4612922/mediaviewer/rm1327992321/?ref_=tt_ov_i',
#  '/title/tt3469052/mediaviewer/rm853926912/?ref_=tt_ov_i',
#  '/title/tt2182614/mediaviewer/rm2844922880/?ref_=tt_ov_i',
#  '/title/tt3143378/mediaviewer/rm1340466176/?ref_=tt_ov_i',
#  '/title/tt1996607/mediaviewer/rm4127510273/?ref_=tt_ov_i',
#  '/title/tt2693442/mediaviewer/rm3159587584/?ref_=tt_ov_i',
#  '/title/tt2720634/mediaviewer/rm2553307648/?ref_=tt_ov_i',
#  '/title/tt6289274/mediaviewer/rm1312728065/?ref_=tt_ov_i',
#  '/title/tt8591092/mediaviewer/rm3189604096/?ref_=tt_ov_i',
#  '/title/tt5189944/mediaviewer/rm1944511488/?ref_=tt_ov_i',
#  '/title/tt4686292/mediaviewer/rm2083417088/?ref_=tt_ov_i',
#  '/title/tt10777760/mediaviewer/rm3174161665/?ref_=tt_ov_i',
#  '/title/tt3184674/mediaviewer/rm333833216/?ref_=tt_ov_i',
#  '/title/tt2398172/mediaviewer/rm3544707841/?ref_=tt_ov_i',
#  '/title/tt2429772/mediaviewer/rm2073170944/?ref_=tt_ov_i',
#  '/title/tt3147968/mediaviewer/rm3111838720/?ref_=tt_ov_i',
#  '/title/tt4671770/mediaviewer/rm2316263936/?ref_=tt_ov_i',
#  '/title/tt0468618/mediaviewer/rm1303552/?ref_=tt_ov_i',
#  '/title/tt0482854/mediaviewer/rm4119466752/?ref_=tt_ov_i',
#  '/title/tt3205964/mediaviewer/rm1889232896/?ref_=tt_ov_i',
#  '/title/tt2949498/mediaviewer/rm345209600/?ref_=tt_ov_i',
#  '/title/tt3532844/mediaviewer/rm1809715200/?ref_=tt_ov_i',
#  '/title/tt6289582/mediaviewer/rm2585014272/?ref_=tt_ov_i',
#  '/title/tt5225092/mediaviewer/rm942800896/?ref_=tt_ov_i',
#  '/title/tt0313103/mediaviewer/rm788619776/?ref_=tt_ov_i',
#  '/title/tt8236556/mediaviewer/rm860451584/?ref_=tt_ov_i',
#  '/title/tt4357294/mediaviewer/rm1726407680/?ref_=tt_ov_i',
#  '/title/tt1841321/mediaviewer/rm3057181696/?ref_=tt_ov_i',
#  '/title/tt6354758/mediaviewer/rm4017518592/?ref_=tt_ov_i',
#  '/title/tt3246872/mediaviewer/rm761928192/?ref_=tt_ov_i',
#  '/title/tt10844620/mediaviewer/rm2918379777/?ref_=tt_ov_i',
#  '/title/tt2389644/mediaviewer/rm3320964096/?ref_=tt_ov_i',
#  '/title/tt0477524/mediaviewer/rm367663616/?ref_=tt_ov_i',
#  '/title/tt0477490/mediaviewer/rm1011845889/?ref_=tt_ov_i',
#  '/title/tt11228748/mediaviewer/rm1296413185/?ref_=tt_ov_i',
#  '/title/tt5766194/mediaviewer/rm3873769216/?ref_=tt_ov_i',
#  '/title/tt10844106/mediaviewer/rm2184305921/?ref_=tt_ov_i',
#  '/title/tt10777780/mediaviewer/rm1921570049/?ref_=tt_ov_i',
#  '/title/tt3243098/mediaviewer/rm1168303872/?ref_=tt_ov_i',
#  '/title/tt2373094/mediaviewer/rm2295718912/?ref_=tt_ov_i',
#  '/title/tt10844172/mediaviewer/rm2927688193/?ref_=tt_ov_i',
#  '/title/tt1982229/mediaviewer/rm3467645952/?ref_=tt_ov_i',
#  '/title/tt1666217/mediaviewer/rm2409096192/?ref_=tt_ov_i',
#  '/title/tt10442802/mediaviewer/rm2592774145/?ref_=tt_ov_i',
#  '/title/tt1370334/mediaviewer/rm2028332032/?ref_=tt_ov_i',
#  '/title/tt2121968/mediaviewer/rm2349287424/?ref_=tt_ov_i',
#  '/title/tt4193068/mediaviewer/rm3657576192/?ref_=tt_ov_i',
#  '/title/tt8834682/mediaviewer/rm882080512/?ref_=tt_ov_i',
#  '/title/tt4083422/mediaviewer/rm1656178432/?ref_=tt_ov_i',
#  53,
#  '/title/tt13394544/mediaviewer/rm1824378881/?ref_=tt_ov_i',
#  '/title/tt12516712/mediaviewer/rm1902422529/?ref_=tt_ov_i',
#  '/title/tt10656392/mediaviewer/rm3018233345/?ref_=tt_ov_i',
#  '/title/tt6720154/mediaviewer/rm3528668160/?ref_=tt_ov_i',
#  '/title/tt5966882/mediaviewer/rm2823129601/?ref_=tt_ov_i',
#  '/title/tt6270712/mediaviewer/rm424097792/?ref_=tt_ov_i',
#  '/title/tt4284216/mediaviewer/rm1839850752/?ref_=tt_ov_i',
#  '/title/tt3855278/mediaviewer/rm1251087360/?ref_=tt_ov_i',
#  '/title/tt3322566/mediaviewer/rm1261333504/?ref_=tt_ov_i',
#  '/title/tt2242048/mediaviewer/rm2351686656/?ref_=tt_ov_i',
#  '/title/tt6385836/mediaviewer/rm3742513920/?ref_=tt_ov_i',
#  '/title/tt3052852/mediaviewer/rm803660800/?ref_=tt_ov_i',
#  '/title/tt6141742/mediaviewer/rm3446159360/?ref_=tt_ov_i',
#  '/title/tt5478592/mediaviewer/rm2794920704/?ref_=tt_ov_i',
#  '/title/tt5689030/mediaviewer/rm4070707968/?ref_=tt_ov_i',
#  '/title/tt4031224/mediaviewer/rm98952192/?ref_=tt_ov_i',
#  '/title/tt2806646/mediaviewer/rm1708847617/?ref_=tt_ov_i',
#  '/title/tt0843176/mediaviewer/rm3242201856/?ref_=tt_ov_i',
#  '/title/tt0932658/mediaviewer/rm2086408960/?ref_=tt_ov_i',
#  '/title/tt6601970/mediaviewer/rm391268608/?ref_=tt_ov_i',
#  '/title/tt5728894/mediaviewer/rm2260209664/?ref_=tt_ov_i',
#  '/title/tt2536522/mediaviewer/rm1272374272/?ref_=tt_ov_i',
#  '/title/tt0477526/mediaviewer/rm1976111104/?ref_=tt_ov_i',
#  '/title/tt12235718/mediaviewer/rm3996580865/?ref_=tt_ov_i',
#  '/title/tt6516076/mediaviewer/rm584855808/?ref_=tt_ov_i',
#  '/title/tt4925000/mediaviewer/rm484842240/?ref_=tt_ov_i',
#  '/title/tt5079024/mediaviewer/rm1207690752/?ref_=tt_ov_i',
#  '/title/tt4128654/mediaviewer/rm740418560/?ref_=tt_ov_i',
#  '/title/tt5309758/mediaviewer/rm3597280512/?ref_=tt_ov_i',
#  '/title/tt3143308/mediaviewer/rm2300259584/?ref_=tt_ov_i',
#  '/title/tt2305397/mediaviewer/rm2288720384/?ref_=tt_ov_i',
#  '/title/tt2745682/mediaviewer/rm2145772544/?ref_=tt_ov_i',
#  '/title/tt2363848/mediaviewer/rm3715425280/?ref_=tt_ov_i',
#  '/title/tt3211198/mediaviewer/rm2228675584/?ref_=tt_ov_i',
#  '/title/tt7475750/mediaviewer/rm3750984448/?ref_=tt_ov_i',
#  '/title/tt9130542/mediaviewer/rm1802856960/?ref_=tt_ov_i',
#  '/title/tt8160064/mediaviewer/rm319517440/?ref_=tt_ov_i',
#  '/title/tt6256484/mediaviewer/rm1978803712/?ref_=tt_ov_i',
#  '/title/tt6157148/mediaviewer/rm662190592/?ref_=tt_ov_i',
#  '/title/tt6058390/mediaviewer/rm225968896/?ref_=tt_ov_i',
#  '/title/tt5797194/mediaviewer/rm2481064448/?ref_=tt_ov_i',
#  '/title/tt4201628/mediaviewer/rm199615488/?ref_=tt_ov_i',
#  '/title/tt3693414/mediaviewer/rm166061056/?ref_=tt_ov_i',
#  '/title/tt3141190/mediaviewer/rm971367424/?ref_=tt_ov_i',
#  '/title/tt8737876/mediaviewer/rm3534796033/?ref_=tt_ov_i',
#  '/title/tt9014894/mediaviewer/rm808615424/?ref_=tt_ov_i',
#  '/title/tt2309828/mediaviewer/rm3093961216/?ref_=tt_ov_i',
#  '/title/tt1819921/mediaviewer/rm2671313152/?ref_=tt_ov_i',
#  102,
#  '/title/tt13634792/mediaviewer/rm870698241/?ref_=tt_ov_i',
#  '/title/tt14515452/mediaviewer/rm3027878657/?ref_=tt_ov_i',
#  '/title/tt8328460/mediaviewer/rm2669662465/?ref_=tt_ov_i',
#  '/title/tt8523042/mediaviewer/rm986616833/?ref_=tt_ov_i',
#  '/title/tt7099334/mediaviewer/rm1553357824/?ref_=tt_ov_i',
#  '/title/tt3693428/mediaviewer/rm1676010496/?ref_=tt_ov_i',
#  '/title/tt2816734/mediaviewer/rm1461039617/?ref_=tt_ov_i',
#  '/title/tt2346947/mediaviewer/rm1877337088/?ref_=tt_ov_i',
#  '/title/tt2255085/mediaviewer/rm1847649280/?ref_=tt_ov_i',
#  '/title/tt2283335/mediaviewer/rm1337797888/?ref_=tt_ov_i',
#  '/title/tt13433812/mediaviewer/rm634964737/?ref_=tt_ov_i',
#  '/title/tt8750956/mediaviewer/rm616012289/?ref_=tt_ov_i',
#  '/title/tt4997992/mediaviewer/rm2676572672/?ref_=tt_ov_i',
#  '/title/tt6032762/mediaviewer/rm321599232/?ref_=tt_ov_i',
#  '/title/tt2593336/mediaviewer/rm1961223168/?ref_=tt_ov_i',
#  '/title/tt2221405/mediaviewer/rm1568334848/?ref_=tt_ov_i',
#  '/title/tt3364882/mediaviewer/rm3008304128/?ref_=tt_ov_i',
#  '/title/tt1500636/mediaviewer/rm2132363264/?ref_=tt_ov_i']

# %%
# Convert all items in the above list to string. This is beacuase I returned the index for series that did not have an image url.
# I also have to do this to avoid getting a type error in the next part of my code.
image_imdb_url_1 = list(map(str, image_imdb_url))

# %%
image_url = []
for i in range(len(image_imdb_url_1)):
  if len(image_imdb_url_1[i]) > 3:
    base_url_1 = 'https://www.imdb.com'
    full_url_1 = base_url_1 + image_imdb_url_1[i]
    request_8 = requests.get(full_url_1,"html.parser")
    eighth_soup = bs(request_8.content)
    img_1 = eighth_soup.find(True, {"class":["MediaViewerImagestyles__PortraitContainer-sc-1qk433p-2 iUyzNI", 
                                                "MediaViewerImagestyles__LandscapeContainer-sc-1qk433p-3 kXRNYt"]})

    if img_1 is not None:
      img_2 = img_1.find('img')['src']
      image_url.append(img_2)
    else:
      image_url.append(str(i))

  else:
    image_url.append(str(i))

# %%
image_url
# Out:
# ['https://m.media-amazon.com/images/M/MV5BZmYwYjc2MmYtYmRjYy00ZmI0LTkyODctNzdlYjYxYWFjMmVhXkEyXkFqcGdeQXVyNDY5MjMyNTg@._V1_.jpg',
#  'https://m.media-amazon.com/images/M/MV5BYTk0Nzk5ZWYtYTNlZi00YjBjLWJhYjctMWMwMmYyMDA5ZjJmXkEyXkFqcGdeQXVyNDY5MjMyNTg@._V1_.jpg',
#  'https://m.media-amazon.com/images/M/MV5BMzRiZWUyN2YtNDI4YS00NTg2LTg0OTgtMGI2ZjU4ODQ4Yjk3XkEyXkFqcGdeQXVyNTI5NjIyMw@@._V1_.jpg',
#  'https://m.media-amazon.com/images/M/MV5BNzQ2MzQzNDktMTg4ZC00ZDE0LThhNmUtYWMxYmI3OTIzYzZlXkEyXkFqcGdeQXVyMzE4MDkyNTA@._V1_.jpg',
#  'https://m.media-amazon.com/images/M/MV5BYjM1NGI1Y2MtZDg3NS00MjNmLWJjMTYtZmE3ZTk1YzgyODhmXkEyXkFqcGdeQXVyNDY5MjMyNTg@._V1_.jpg',
#  'https://m.media-amazon.com/images/M/MV5BYTA2MTZhMmQtN2VmOC00NTc4LWE2ZWQtNzc5ZDk5YWE4NDdlXkEyXkFqcGdeQXVyMzE4MDkyNTA@._V1_.jpg',
#  'https://m.media-amazon.com/images/M/MV5BMmJlMmU2NmItOGQyOC00ZDNhLWJkNGYtZjU4ZTgwNzA0NjBkXkEyXkFqcGdeQXVyMzE4MDkyNTA@._V1_.jpg',
#  'https://m.media-amazon.com/images/M/MV5BMDBkZjE2NzMtZWNjMC00NmE4LTkyNTQtNzFhNzk2Mjg0NmE5XkEyXkFqcGdeQXVyMzQ2MDUxMTg@._V1_.jpg',
#  'https://m.media-amazon.com/images/M/MV5BMWU0OGRjYjUtZDE1Ni00MTJmLWI4ZjAtZjYzMjM4M2VkODRhXkEyXkFqcGdeQXVyNjc3MjQzNTI@._V1_.jpg',
#  'https://m.media-amazon.com/images/M/MV5BN2ZhN2QxNGQtOGYwZi00MjIxLWE4MDUtYzFmYjZhMTllYWVhXkEyXkFqcGdeQXVyNTU5MjI4MTg@._V1_.jpg',
#  'https://m.media-amazon.com/images/M/MV5BYjc4MjI0MDgtMjI4Ni00ZWUyLTk2YjMtOGJjMjVhMDEwMmE1XkEyXkFqcGdeQXVyNjc3MjQzNTI@._V1_.jpg',
#  'https://m.media-amazon.com/images/M/MV5BZGIyYWZkNzQtMzdhYS00ZTFhLWI5M2ItZWRjNTAwOWJlYjcyXkEyXkFqcGdeQXVyNjc3MjQzNTI@._V1_.jpg',
#  'https://m.media-amazon.com/images/M/MV5BZjVjZWI3NzAtZTc0OS00NTQ3LWE5MjMtZTNkZGNlOTJlMWIyXkEyXkFqcGdeQXVyNzk0NTA5NQ@@._V1_.jpg',
#  'https://m.media-amazon.com/images/M/MV5BYTFmZWUxMDktNWE1Ny00NTdkLWEyOWUtY2E1OTk3NjRiY2I0XkEyXkFqcGdeQXVyMjMxNTAxNDk@._V1_.jpg',
#  'https://m.media-amazon.com/images/M/MV5BMDAzYjNlZGItNzk4OS00NjFmLWIxMjAtMWU3M2Q1Mzk4NzNlXkEyXkFqcGdeQXVyNTM3MDMyMDQ@._V1_.jpg',
#  'https://m.media-amazon.com/images/M/MV5BNWE1ZjQ5NDktZWFlZi00OTVjLWEwNWMtYWQyNmRlYjViZjM4XkEyXkFqcGdeQXVyMTEwNDU1MzEy._V1_.jpg',
#  'https://m.media-amazon.com/images/M/MV5BYjU5ZmZmODItODZkZi00YzA4LTg4NjUtMTJmZWFmMjVjYmZhXkEyXkFqcGdeQXVyMjIyNzU0OA@@._V1_.jpg',
#  'https://m.media-amazon.com/images/M/MV5BMjRiZGFiN2UtNDk4OC00OTdiLTk0ZWQtYTlkZmMyODFiZWEyXkEyXkFqcGdeQXVyNjc3MjQzNTI@._V1_.jpg',
#  'https://m.media-amazon.com/images/M/MV5BODhjYzc3ZmQtNjFiNi00Mjk3LTllMGEtOGVhN2VlM2UxZmYyXkEyXkFqcGdeQXVyMzE4MDkyNTA@._V1_.jpg',
#  'https://m.media-amazon.com/images/M/MV5BMDc0ZWM2MjgtYTE5My00NDg1LTk5ZjEtNzNmYzY0NzZmNzg0XkEyXkFqcGdeQXVyMjIyNzU0OA@@._V1_.jpg',
#  'https://m.media-amazon.com/images/M/MV5BNjUyZmEyM2QtZmY2NS00ZTdlLTg0OWYtODI1OGQ1YmQ3MmFkXkEyXkFqcGdeQXVyNjc3MjQzNTI@._V1_.jpg',
#  'https://m.media-amazon.com/images/M/MV5BNzIxYjY1NDktMDUxMy00MTJlLTg3MTctODdiMzk5YzBlOTU2XkEyXkFqcGdeQXVyMzA1NzczOTU@._V1_.jpg',
#  'https://m.media-amazon.com/images/M/MV5BM2YyY2ZkNjgtYTRmMS00YmNkLTg2MzAtZWVjZmNmNGZhMDk2XkEyXkFqcGdeQXVyMjIyNzU0OA@@._V1_.jpg',
#  'https://m.media-amazon.com/images/M/MV5BYzY5OWZmM2EtNzc0My00YzBkLTgyNWItOWIxNTYwZDRiOGY4XkEyXkFqcGdeQXVyNjc3MjQzNTI@._V1_.jpg',
#  'https://m.media-amazon.com/images/M/MV5BYjU2NWEzNTMtZTA0OS00MTIzLWJiNzYtZWM2YzI4MWMxMTIyXkEyXkFqcGdeQXVyNjc3MjQzNTI@._V1_.jpg',
#  'https://m.media-amazon.com/images/M/MV5BZTU0YjliOTAtODEyNy00MDdjLWE3YTYtZTEwYTc4NGJjZWIzXkEyXkFqcGdeQXVyNzI5OTQ2NTE@._V1_.jpg',
#  'https://m.media-amazon.com/images/M/MV5BMTY2OWFkZTktZjUzYS00NGI5LTg2MmYtNjliMmIxNjYyOWJiXkEyXkFqcGdeQXVyMjg0MTI5NzQ@._V1_.jpg',
#  'https://m.media-amazon.com/images/M/MV5BN2QyOWE2MWMtMzI2ZC00MDQ3LWI4MjUtMGYzNjFkOWRlYzJmXkEyXkFqcGdeQXVyMzI2NzE3MDc@._V1_.jpg',
#  'https://m.media-amazon.com/images/M/MV5BZDYyYzJjZTktZmEyNy00Mzc3LWFmZjMtYTc1YjcwODE1YjU0XkEyXkFqcGdeQXVyNjc3MjQzNTI@._V1_.jpg',
#  'https://m.media-amazon.com/images/M/MV5BNTEyOGVkMDUtZjA4Yi00MTQ4LTk1YWMtYmMxOTFjZTM4NzAwXkEyXkFqcGdeQXVyMzE4MDkyNTA@._V1_.jpg',
#  'https://m.media-amazon.com/images/M/MV5BNDhhZmI5YmYtOTU0ZS00M2FhLTgyMzktM2ViMzRhNzFmM2ZjXkEyXkFqcGdeQXVyNTkzMjQ1MTU@._V1_.jpg',
#  'https://m.media-amazon.com/images/M/MV5BZDcwYzg3ODUtNWQ3My00ZTkyLWJjZDUtNDA4YzQ3NmU4MzQxXkEyXkFqcGdeQXVyMjgzMDQzNDc@._V1_.jpg',
#  'https://m.media-amazon.com/images/M/MV5BNzY5MWY0YjgtZTViYi00NGZkLThiOGUtY2M2NjcwODg3NTUxXkEyXkFqcGdeQXVyMjM0NTM5MTA@._V1_.jpg',
#  'https://m.media-amazon.com/images/M/MV5BNzVlNWM2NTAtNmM4Yi00MGQxLWI3OTYtMTkzNjY0ZGZhYWFmXkEyXkFqcGdeQXVyMjM0NTM5MTA@._V1_.jpg',
#  'https://m.media-amazon.com/images/M/MV5BMTM2MWE4ODUtZmY4Yy00NDY0LWIyOTQtYWViNDM1MjI0YWM5XkEyXkFqcGdeQXVyMTA3NTczOTIx._V1_.jpg',
#  'https://m.media-amazon.com/images/M/MV5BOGFiMmI3N2UtMDMxMS00OWQzLWFkNTktM2VhMzU2ZTYzZjViXkEyXkFqcGdeQXVyMjgzMDQzNDc@._V1_.jpg',
#  'https://m.media-amazon.com/images/M/MV5BYzVkOWVmM2YtMmM5MC00MzZkLWFlOTYtMjhjYTZkNDI4NGM3XkEyXkFqcGdeQXVyMzE1MjAxNzU@._V1_.jpg',
#  'https://m.media-amazon.com/images/M/MV5BMmE1MGI1NmItMDVjOC00NDBmLThlNjYtYTMzMDFmMTE4M2YwXkEyXkFqcGdeQXVyNjc3MjQzNTI@._V1_.jpg',
#  'https://m.media-amazon.com/images/M/MV5BMDk2MDAyNmYtY2VlNS00N2EzLWE4ZDEtMmI0N2ViYzk4ODU4XkEyXkFqcGdeQXVyNjc3MjQzNTI@._V1_.jpg',
#  'https://m.media-amazon.com/images/M/MV5BZjAwZTU3NzUtZDExNi00NDk4LTkzYWItNGEzNDUwOWU0M2Q5L2ltYWdlL2ltYWdlXkEyXkFqcGdeQXVyMzE4MDkyNTA@._V1_.jpg',
#  'https://m.media-amazon.com/images/M/MV5BYzY1YWY1YmMtZjIxMC00OTIzLWFmNjAtYjA2ZWM1MjUzOTgyXkEyXkFqcGdeQXVyMTEwNDU1MzEy._V1_.jpg',
#  'https://m.media-amazon.com/images/M/MV5BMGNiYjRlZDctOTNiNC00NzZmLTlhMjMtMmQ0YmNiNWYzYTU5XkEyXkFqcGdeQXVyNjI4NDY5ODM@._V1_.jpg',
#  'https://m.media-amazon.com/images/M/MV5BNjdjMjQzODctZGMwMC00MzMwLTkwNmYtYzBlZjIzNzRiMjc5XkEyXkFqcGdeQXVyNDk3NDAzODE@._V1_.jpg',
#  'https://m.media-amazon.com/images/M/MV5BM2FmYmE2NGEtOTAyNy00YTMwLTljYjMtNDVjNDAxNzc0ZGRmXkEyXkFqcGdeQXVyMzE4MDkyNTA@._V1_.jpg',
#  'https://m.media-amazon.com/images/M/MV5BODAxZDViMjUtMmI1Yy00MDhhLTllNWQtN2E3OWMxN2Y5MGI3XkEyXkFqcGdeQXVyMTA4OTE3MTI@._V1_.jpg',
#  'https://m.media-amazon.com/images/M/MV5BZGFlZjMzOGUtNDRkOC00MmZkLTlmZjUtNWNkMmQzZTk0NjY5XkEyXkFqcGdeQXVyMzE4MDkyNTA@._V1_.jpg',
#  'https://m.media-amazon.com/images/M/MV5BYzMwN2Q4MDktZDYxNy00OTVjLWFmYWQtNTUzMGIyZTQ5Nzg4XkEyXkFqcGdeQXVyMjIyNzU0OA@@._V1_.jpg',
#  'https://m.media-amazon.com/images/M/MV5BYzcyODg1OTMtYzYwZi00ODQwLTljYzctYmVmYmIwZWRjOTFjXkEyXkFqcGdeQXVyNDQwMDYzOTU@._V1_.jpg',
#  'https://m.media-amazon.com/images/M/MV5BZmNmMTdhNzItNjM4ZC00NjgxLWIwNWMtMzkxZWZkZWVjMzZkXkEyXkFqcGdeQXVyMzE4MDkyNTA@._V1_.jpg',
#  'https://m.media-amazon.com/images/M/MV5BN2RhYjRiZWEtNzhjYS00MDRjLTkwMzktMTllN2E4ZjA5MGM3XkEyXkFqcGdeQXVyNTM3MDMyMDQ@._V1_.jpg',
#  'https://m.media-amazon.com/images/M/MV5BMjZkM2M4MzctNTE4NC00NDUxLTkwZWItOWQ1YjNhNDBhYjBkXkEyXkFqcGdeQXVyNjc2NzM4MQ@@._V1_.jpg',
#  'https://m.media-amazon.com/images/M/MV5BYjE0MjgwNzYtN2UwNS00MmEyLWIzMGEtNjIyOGRkYzczZDQzXkEyXkFqcGdeQXVyNjc3MjQzNTI@._V1_.jpg',
#  'https://m.media-amazon.com/images/M/MV5BMGIzZmQ4YmUtZGQ4NC00OTkyLWE1MGUtMTQ3N2Y3N2E2NWEyXkEyXkFqcGdeQXVyODAzNzAwOTU@._V1_.jpg',
#  '53',
#  'https://m.media-amazon.com/images/M/MV5BZmY2NjFjODYtZWZkZi00MjI2LWE1ZjQtMGM3NDg4MDE5MzdlXkEyXkFqcGdeQXVyNDU4MDQ0MjM@._V1_.jpg',
#  'https://m.media-amazon.com/images/M/MV5BZDg3Y2RkMmItYWViMS00OTRjLWI1NTktMTJhYTkxZGUzZGIyXkEyXkFqcGdeQXVyMjQ2OTU4Mjg@._V1_.jpg',
#  'https://m.media-amazon.com/images/M/MV5BNWE4OTYwYzItN2E5Ny00MjQ3LTg0OTctNDRiMmEwZDZiMzEyXkEyXkFqcGdeQXVyNzk0NTA5NQ@@._V1_.jpg',
#  'https://m.media-amazon.com/images/M/MV5BNTdjOTUwYmYtNWQ0MC00ZWRkLWI0NmYtMzY5NThhYWVhNGM4XkEyXkFqcGdeQXVyNzk0NTA5NQ@@._V1_.jpg',
#  'https://m.media-amazon.com/images/M/MV5BMGI1MDIzNTItMzg1ZS00MmFkLWFlZDEtYmVmZWVkMDZkM2U3XkEyXkFqcGdeQXVyMTMxODk2OTU@._V1_.jpg',
#  'https://m.media-amazon.com/images/M/MV5BZGNmMDk5ODYtZjUzOS00NDFiLWI2NTAtZjc2MDRkMDM0YjY0XkEyXkFqcGdeQXVyNzM0NDk0MDg@._V1_.jpg',
#  'https://m.media-amazon.com/images/M/MV5BZGE3NGI4ZDQtNzJjOC00Y2ZjLTgxNGItNzhmZjU4YWM0ZmI4XkEyXkFqcGdeQXVyNjUyNzU5NzA@._V1_.jpg',
#  'https://m.media-amazon.com/images/M/MV5BMzU2NWQ3ZmYtYWFlNC00MDMzLWI2MWYtN2U5MWI5MTMwMTk5XkEyXkFqcGdeQXVyNzk0NTA5NQ@@._V1_.jpg',
#  'https://m.media-amazon.com/images/M/MV5BNThlM2ZjYzItYzhmYS00MjI5LTg5YTAtYzZlN2FjNmIwYzc3XkEyXkFqcGdeQXVyMTMxODk2OTU@._V1_.jpg',
#  'https://m.media-amazon.com/images/M/MV5BNjA3NDI4YzAtNGEyZi00MDQ2LTgxNzItMzk4Yjk4N2VlMGM2XkEyXkFqcGdeQXVyMzE4MDkyNTA@._V1_.jpg',
#  'https://m.media-amazon.com/images/M/MV5BNDU2M2M2OWEtMGRlNi00MjFlLWEyMmEtNmJhY2VmOGFhMDlmXkEyXkFqcGdeQXVyNzM0NDk0MDg@._V1_.jpg',
#  'https://m.media-amazon.com/images/M/MV5BN2IxMmFjZDMtOGRlNi00MTM3LWI5ZjQtMWY0NzM2MDIwYWM2XkEyXkFqcGdeQXVyNTM3MDMyMDQ@._V1_.jpg',
#  'https://m.media-amazon.com/images/M/MV5BN2RiYjQzNDUtMzZlOC00NjQ3LWFhMzctZTYxYWM4NTU4YTgyXkEyXkFqcGdeQXVyNTM3MDMyMDQ@._V1_.jpg',
#  'https://m.media-amazon.com/images/M/MV5BMTAxNjllYjctNWVkMi00ZjAxLWFlYmUtODMzYzQ5NzRkNDg3XkEyXkFqcGdeQXVyMzE4MDkyNTA@._V1_.jpg',
#  'https://m.media-amazon.com/images/M/MV5BYzcwOWMwYjEtNmYyZS00MzY0LWI4YzctMTg5MWY5ZjFkZDQyXkEyXkFqcGdeQXVyNTM3MDMyMDQ@._V1_.jpg',
#  'https://m.media-amazon.com/images/M/MV5BNzU2MTFlZjItYTc0MS00NWNkLWJiODYtNmNkZmY5ZGM1OTU0XkEyXkFqcGdeQXVyMjIyNzU0OA@@._V1_.jpg',
#  'https://m.media-amazon.com/images/M/MV5BMThlNzBlMTMtZWJhNi00OWFlLThlOGUtZmMwNGUwMTIzNzNkXkEyXkFqcGdeQXVyMTI1OTY3MzM3._V1_.jpg',
#  'https://m.media-amazon.com/images/M/MV5BODk1OGIzZTgtN2Q0Yy00NTM1LWE0NmQtZDE4YzY4ZWIxOTY4XkEyXkFqcGdeQXVyMjIyNzU0OA@@._V1_.jpg',
#  'https://m.media-amazon.com/images/M/MV5BYThjNzg3ZGUtZGYzOC00ZGM5LThlMzMtZjFlOWQ5M2JhZDhjXkEyXkFqcGdeQXVyNjU3MzA0NjE@._V1_.jpg',
#  'https://m.media-amazon.com/images/M/MV5BNWU1NzgyMjctZTUyMy00N2FjLTlkMzQtNzg4YmRiYTliNThmXkEyXkFqcGdeQXVyMjIyNzU0OA@@._V1_.jpg',
#  'https://m.media-amazon.com/images/M/MV5BNmI0YzVjZDMtMjUxZi00NzRlLWI5ODctNTVkODA1OGZkYTA1XkEyXkFqcGdeQXVyNjc3MjQzNTI@._V1_.jpg',
#  'https://m.media-amazon.com/images/M/MV5BZGMzODJlY2YtNDg3My00NTdkLWFmY2EtZGVjMjdlNWE1ZTEwXkEyXkFqcGdeQXVyNTM3MDMyMDQ@._V1_.jpg',
#  'https://m.media-amazon.com/images/M/MV5BNDg3ZmVhZDAtZjI2NS00ZjNjLTkzMWItMjBhYjNiZGY4MzQ1XkEyXkFqcGdeQXVyNjU3MzA0NjE@._V1_.jpg',
#  'https://m.media-amazon.com/images/M/MV5BMDAxMTM5ZmItYWQ0OS00YzkxLTkzNjUtMTZjYTQ1NDE2YzE4XkEyXkFqcGdeQXVyMTEzMTI1Mjk3._V1_.jpg',
#  'https://m.media-amazon.com/images/M/MV5BNGIyYjM2YjktZTliMi00YzQ4LThkZDctYzY5NDVhMjgwZjA0XkEyXkFqcGdeQXVyMzE4MDkyNTA@._V1_.jpg',
#  'https://m.media-amazon.com/images/M/MV5BM2ExNGE4ZjItMmY5My00ZDU5LWJiMzMtOTFjMDRmNWVlMzZiXkEyXkFqcGdeQXVyMzE4MDkyNTA@._V1_.jpg',
#  'https://m.media-amazon.com/images/M/MV5BNzgzY2ZmYzEtZTVmYS00MDg5LWFhZGMtNDNjN2Q1YmFlNjEyXkEyXkFqcGdeQXVyMzE4MDkyNTA@._V1_.jpg',
#  'https://m.media-amazon.com/images/M/MV5BZWI0ZTI3Y2EtZDRiZC00MDk0LWEwYTQtOTU4YjY3M2NjZDIyXkEyXkFqcGdeQXVyNTM3MDMyMDQ@._V1_.jpg',
#  'https://m.media-amazon.com/images/M/MV5BNDI5YWUxMzctMTA1Ny00MTIwLWI1YmMtNzhiMDdkZGIyMjVmXkEyXkFqcGdeQXVyODA4ODIwNDM@._V1_.jpg',
#  'https://m.media-amazon.com/images/M/MV5BMWY5YTFhZDUtYWJiNy00Y2E4LThmMjYtNDAxYzExYzBjOTc2XkEyXkFqcGdeQXVyNjk2NjIzMDI@._V1_.jpg',
#  'https://m.media-amazon.com/images/M/MV5BYjYwNTY3ZGMtYzc4ZC00MWUwLTllN2MtYmFiZjllMjNhOWRjXkEyXkFqcGdeQXVyMjM0NTM5MTA@._V1_.jpg',
#  'https://m.media-amazon.com/images/M/MV5BZTc1NmMzZmUtNGY1ZC00MDNmLWE1MzQtM2NhNWZhOGQ1ODM4XkEyXkFqcGdeQXVyNDQ1MDA5OTM@._V1_.jpg',
#  'https://m.media-amazon.com/images/M/MV5BYjVlZjE0MzAtYTdlYy00ZmZjLWIyMWMtNWVjMzZkMTY3ZmI1XkEyXkFqcGdeQXVyODA4ODIwNDM@._V1_.jpg',
#  'https://m.media-amazon.com/images/M/MV5BZTgzN2I4MWItNTFlNi00YjNhLTkwNTgtY2UzOWEwZjgwOGFlXkEyXkFqcGdeQXVyODA4ODIwNDM@._V1_.jpg',
#  'https://m.media-amazon.com/images/M/MV5BNTkxN2M5Y2EtOTdjZi00ZDg1LTgwMmItMTRmZmEzMjkyMTg1XkEyXkFqcGdeQXVyNjc3MjQzNTI@._V1_.jpg',
#  'https://m.media-amazon.com/images/M/MV5BMTZiMzZjZDUtMmU2MS00MWU4LWFmODYtZmU3ZjlhODYwMGJkXkEyXkFqcGdeQXVyMzE4MDkyNTA@._V1_.jpg',
#  'https://m.media-amazon.com/images/M/MV5BN2UwMzUwYTMtNDg1YS00YTE0LTliMWEtOWJjMTZiYTVlOWNmXkEyXkFqcGdeQXVyMTMxODk2OTU@._V1_.jpg',
#  'https://m.media-amazon.com/images/M/MV5BYmYwMjRjYzgtMmM3Ni00NWVkLTg3Y2ItNDM1N2FmNTg3YzZlXkEyXkFqcGdeQXVyNzk0NTA5NQ@@._V1_.jpg',
#  'https://m.media-amazon.com/images/M/MV5BYjY2OTlmNDMtYjIzNi00OWM2LTg5YjItMmY0ZTc3ZmM4Yjc5XkEyXkFqcGdeQXVyNzA5NDY0MDk@._V1_.jpg',
#  'https://m.media-amazon.com/images/M/MV5BYjVlMjY0OGQtYmIzNC00YjNjLWI4N2UtMDhjMWNlN2U4YzE5XkEyXkFqcGdeQXVyMjMxNTAxNDk@._V1_.jpg',
#  'https://m.media-amazon.com/images/M/MV5BMGM2NjYzZWMtN2RjNi00YWZkLTgzNjgtYmQ3Yzg5MzRkNzQ3XkEyXkFqcGdeQXVyMzE4MDkyNTA@._V1_.jpg',
#  'https://m.media-amazon.com/images/M/MV5BNDViYmViNWItMTY0Ny00YWI0LTg2MDktY2M1NDI5NzUyYWM4XkEyXkFqcGdeQXVyMzE4MDkyNTA@._V1_.jpg',
#  'https://m.media-amazon.com/images/M/MV5BZGVmMWM5MTItMWE1Yi00MmZiLWI4ODUtZTg3OGVhZWI4NDdiL2ltYWdlL2ltYWdlXkEyXkFqcGdeQXVyNjk2NjIzMDI@._V1_.jpg',
#  'https://m.media-amazon.com/images/M/MV5BMjFkNDc0ZDEtYzk1ZC00ZDZlLWJhZTgtNGZmMmMzMTJiNzc0XkEyXkFqcGdeQXVyMjIyNzU0OA@@._V1_.jpg',
#  'https://m.media-amazon.com/images/M/MV5BNGI0ZjA0ZWUtNTllZi00NjVlLWJhZjEtMWJhZWNiYzg3NTNlXkEyXkFqcGdeQXVyMTE2MDU0NzAw._V1_.jpg',
#  'https://m.media-amazon.com/images/M/MV5BOTNhNWI1NmYtYTU4Yy00NjdiLThkYTQtY2IwMWZiMmI2OTk2XkEyXkFqcGdeQXVyNzk0NTA5NQ@@._V1_.jpg',
#  'https://m.media-amazon.com/images/M/MV5BMzg0NWM0OWQtMDNkOS00YzBmLWI1ODktZjA5YTJmZjBjY2Q2XkEyXkFqcGdeQXVyNTM3MDMyMDQ@._V1_.jpg',
#  'https://m.media-amazon.com/images/M/MV5BMmE4MGY5YzQtYWI0Zi00MzY0LWIwZTYtMGRkZmYwMzZlNDg1XkEyXkFqcGdeQXVyOTExNTUxNTE@._V1_.jpg',
#  '102',
#  'https://m.media-amazon.com/images/M/MV5BMWFhN2M4MzAtOGUxYi00YzVhLWI0NDUtMzQ0MTFjMGU2NGIwXkEyXkFqcGdeQXVyNDU4MDQ0MjM@._V1_.jpg',
#  'https://m.media-amazon.com/images/M/MV5BZTVmYmI2ZTItODQ3OC00YzZiLTgyOTktMWNiMTVjZmZjYzQ5XkEyXkFqcGdeQXVyNDY5MjMyNTg@._V1_.jpg',
#  'https://m.media-amazon.com/images/M/MV5BMDEwNDc5YWEtN2FiMi00ODhlLWI4ZGQtYzcxZmE2NDhhMWI5XkEyXkFqcGdeQXVyODc0OTEyNDU@._V1_.jpg',
#  'https://m.media-amazon.com/images/M/MV5BNDYwNjViZWUtMDU0NC00OTNmLTlmNWItNjFkODM1ZjgwZTZhXkEyXkFqcGdeQXVyNjc3MjQzNTI@._V1_.jpg',
#  'https://m.media-amazon.com/images/M/MV5BZTg1M2RmMDAtZWRhZC00NDNjLWJhMmMtZDZlZjI2OTM4NWI1XkEyXkFqcGdeQXVyNzk0NTA5NQ@@._V1_.jpg',
#  'https://m.media-amazon.com/images/M/MV5BY2M5M2QzYTgtOWU2ZC00YzY5LWJmMjMtOGRmZTk5MWIzMDIwXkEyXkFqcGdeQXVyODQ1MTcyMDM@._V1_.jpg',
#  'https://m.media-amazon.com/images/M/MV5BMzFjZjJiMDMtNDA1ZS00MmJjLWFjYzQtNWU4M2I2OTQ0YTJlXkEyXkFqcGdeQXVyNDY5MjMyNTg@._V1_.jpg',
#  'https://m.media-amazon.com/images/M/MV5BNzYwZTA1ZGYtYmNhNC00NDdmLWIwY2ItOGNkN2QyNDU2ZjE2XkEyXkFqcGdeQXVyNDI3NjcxMDA@._V1_.jpg',
#  'https://m.media-amazon.com/images/M/MV5BNWFmZTlkZjItNWQ5OS00ZWMwLWJlNmItNDlmNmQyNzdiZWE0XkEyXkFqcGdeQXVyMzE4MDkyNTA@._V1_.jpg',
#  'https://m.media-amazon.com/images/M/MV5BZTgxZDBkZDgtM2IxOS00MzNiLWI3MmEtMWI3NjIxNmFkYmU3XkEyXkFqcGdeQXVyNTAwNzc3ODg@._V1_.jpg',
#  'https://m.media-amazon.com/images/M/MV5BYWIwYTg2Y2YtYzEwNy00Y2Y0LWFkZjktNjBlMWZhNDY2NGE0XkEyXkFqcGdeQXVyNDY5MjMyNTg@._V1_.jpg',
#  'https://m.media-amazon.com/images/M/MV5BOGVjMjhhYzEtZjA3YS00NDA1LTg0ZGQtYTQ2MzJlOGU1MDBkXkEyXkFqcGdeQXVyMzE4MDkyNTA@._V1_.jpg',
#  'https://m.media-amazon.com/images/M/MV5BYjc3Y2UxZjMtZGM0NS00NTU2LTljMWYtNzc3YWMzY2Y1YTA1XkEyXkFqcGdeQXVyODA2MDkxNDI@._V1_.jpg',
#  'https://m.media-amazon.com/images/M/MV5BZmNjNzI0NzQtNzIzZS00ODcwLThiNWQtMDM1NmE0ODU2Nzk2XkEyXkFqcGdeQXVyMzE4MDkyNTA@._V1_.jpg',
#  'https://m.media-amazon.com/images/M/MV5BMDkxYWEzMTYtNTFiZS00NDMxLTkyOGQtNGI5MDRhZGExNmU5XkEyXkFqcGdeQXVyMTQyMjYyODk@._V1_.jpg',
#  'https://m.media-amazon.com/images/M/MV5BYjBmODgzMjEtODJkZC00NTg3LWJlNjEtNmEyNWNjNjg3ODIxXkEyXkFqcGdeQXVyODQ2NjQ3MTM@._V1_.jpg',
#  'https://m.media-amazon.com/images/M/MV5BYWVkMzEwNGQtYWRlNS00YWZkLWIyZjItN2ExNTIzMDliMGIxXkEyXkFqcGdeQXVyMzM4MjM0Nzg@._V1_.jpg',
#  'https://m.media-amazon.com/images/M/MV5BYWEyNTY0ZWYtMjNkZi00MzIyLWI3YTEtNWU5NjllODIwOTJlXkEyXkFqcGdeQXVyNzMwOTY2NTI@._V1_.jpg']

# %%
len(image_url),len(unique_series)
# Out:
# (121, 121)

# %%
#getting a count of the total images downloaded
img_count = 0
for i in range(len(image_url)):
  if len(image_url[i]) > 3:
    save_path = '/content/series_images' #path or folder where images should be downloaded to
    file_name = unique_series[i] + ".jpg" #using each series name to save its corresponding image
    image_name = os.path.join(save_path, file_name)

    downloaded_image = requests.get(image_url[i],"html.parser", stream=True).content
    with open(image_name, "wb") as f:
      f.write(downloaded_image)
      img_count += 1
  else:
    pass

print(str(img_count) + " images scraped successfully, \nCheck this folder for your images: '%s' "%save_path)
# Out:
# 119 images scraped successfully,
# Check this folder for your images: '/content/series_images'

# %% [markdown]
# ## Downloading the data tables

# %%
actors_df.to_csv(r'/content/series_tables/actors_data.csv', index = False, header = True)
imdb_df.to_csv(r'/content/series_tables/imdb_data.csv', index = False, header = True)
print('Files saved successfully')
# Out:
# Files saved successfully

# %%
#download folders from google colab to my laptop
import shutil
shutil.make_archive('series_images','zip','series_images')
shutil.make_archive('series_tables','zip','series_tables')

# %% [markdown]
# ## Link to Other Pages

# %% [markdown]
# ### Thank you for taking time to study my notebook.
# ### You can use the links below to view my other pages
#
# [Medium](https://oluwafunmilayo.medium.com/)
#
# [Tableau](https://public.tableau.com/profile/oluwafunmilayo8574)
#
# [LinkedIn Page](https://www.linkedin.com/in/oluwafunmilayo-sofuwa-79454390/)
